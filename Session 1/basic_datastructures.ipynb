# %% [markdown]
# #List

# %%
li= [1,2,3,'four' , 'five']
li
# Out:
# [1, 2, 3, 'four', 'five']

# %%
li.append(6)
print(li)
li.append('seven')
print(li)
# Out:
# [1, 2, 3, 'four', 'five', 6, 6]
# [1, 2, 3, 'four', 'five', 6, 6, 'seven']

# %%
li.remove('five')
li
# Out:
# [1, 2, 3, 'four', 6, 6, 'seven']

# %%
unsorted= [9,2,5,1,7,3,8,4]
print("unsorted list: ", unsorted)
sorted= unsorted.sort()
print('sorted list', sorted)
# Out:
# unsorted list:  [9, 2, 5, 1, 7, 3, 8, 4]
# sorted list None

# %% [markdown]
# ## List comprehension

# %%
cube = [n**3 for n in range (0,10)]
print(cube)
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729]

# %% [markdown]
# # Dictionary

# %%
colors = { 'r': 'red', 'g':'green', 3:'red', 1:2}
colors
# Out:
# {'r': 'red', 'g': 'green', 3: 'red', 1: 2}

# %%
colors['g']
# Out:
# 'green'

# %%
colors[1]= 'one'
colors
# Out:
# {'r': 'red', 'g': 'green', 3: 'red', 1: 'one'}

# %%
colors['li']= li
colors
# Out:
# {'r': 'red', 'g': 'green', 3: 'red', 1: 'one', 'li': [1, 2, 3, 'four', 'five']}

# %%
colors['li'].remove(3)
colors
# Out:
# {'r': 'red', 'g': 'green', 3: 'red', 1: 'one', 'li': [1, 2, 'four', 'five']}

# %% [markdown]
# # Tuple

# %%
no= (1,2,3,4)
no
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# # Set:
# can't contain recurring values

# %%
no= (1,2,3,4,5,5,5,6,7,6,6)
setno= set(no)
setno
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
name= 'harry'
setname= set(name)
color= 'red'
setcolor= set(color)
print(setcolor)
setname
# Out:
# {'e', 'r', 'd'}
# {'a', 'h', 'r', 'y'}

# %%
#union operation
setcolor.union(setname)
# Out:
# {'a', 'd', 'e', 'h', 'r', 'y'}
